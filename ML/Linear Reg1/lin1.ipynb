# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn import linear_model as lnr

# %%
df=pd.read_excel('data1.xlsx',index_col=0)
df.head()
# Out:
#        Area   Price
# Index
# 0      2600  518000
# 1      2800  523000
# 2      3000  578000
# 3      3200  635000
# 4      3400  601000

# %%
plt.xlabel('Area')
plt.ylabel('Price')
plt.scatter(df.Area,df.Price,color='r',marker='+')
plt.show()

# %%
reg=lnr.LinearRegression()
reg.fit(df[['Area']],df[['Price']])
# Out:
# LinearRegression()

# %%
reg.predict([[7500]])
# Out:
# /opt/anaconda3/envs/ml_env/lib/python3.11/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[1154620.]])

# %%
dff=pd.read_excel('test.xlsx') 
dff.head(3)
# Out:
#    Area
# 0  3079
# 1  3350
# 2  3802

# %%
dff['Price']=reg.predict(dff[['Area']]).astype(int)

# %%
dff.head()
# Out:
#    Area   Price
# 0  3079  566962
# 1  3350  602984
# 2  3802  663066
# 3  4340  734579
# 4  4900  809017

# %%
dff.to_csv('test_prediction.csv')

# %%
plt.xlabel('Area')
plt.ylabel('Price')
plt.scatter(df.Area,df.Price,color='r',marker='+')
plt.plot(df.Area,df.Price)
plt.show()

# %%
plt.xlabel('Area')
plt.ylabel('Price')
plt.scatter(df.Area, df.Price, color='r', marker='+')
df_sorted = df.sort_values('Area')
plt.plot(df_sorted.Area, reg.predict(df_sorted[['Area']]), color='blue')

plt.show()
